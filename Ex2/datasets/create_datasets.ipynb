# %% [markdown]
# # dreate dummy datasets

# %% [markdown]
# https://chart-studio.plotly.com/create/?fid=SolClover:113#/

# %% [markdown]
# # hyperplane

# %%
df
# Out:
#               X          Y1         Y2          Y3          Y4          Y5  \
# 55   -82.185041 -193.065661  78.965515 -134.381666  185.069629  103.413987
# 344  -28.771949  -56.659187  31.648173  -32.497327   77.101444   28.919654
# 829   56.705712  134.650424 -58.894317   85.075931 -108.128669  -81.848873
# 609   23.347815   43.341916 -20.869511   11.035881  -27.259906  -18.304438
# 38  -103.028988 -186.541695  73.053886 -129.003799  190.822980  119.853322
# ..          ...         ...        ...         ...         ...         ...
# 86   -88.193548 -173.552195  84.029084  -94.799855  165.609272  111.202309
# 703   32.110412   90.135489 -36.177583   53.782750  -68.296640  -53.692567
# 873   71.092770  143.909749 -51.589581   86.989603 -146.757608 -104.704179
# 712   51.473909   92.267300 -46.978625   78.178554  -88.321634  -49.683691
# 715   37.609128   86.872333 -38.090850   56.460409 -100.037885  -47.541448
#
#             Y6          Y7          Y8          Y9         Y10  label
# 55   18.134022 -151.346101 -228.161300  192.963518 -246.903102      0
# 344   4.236540  -36.767386  -86.000857   63.515610  -93.010015      1
# 829 -14.084076  113.019450  192.430975 -142.505430  189.992476      3
# 609 -25.754458   27.941593   55.608443  -36.798316   83.700191      2
# 38   31.687500 -146.669629 -241.699804  218.293090 -260.995958      0
# ..         ...         ...         ...         ...         ...    ...
# 86   24.979762 -124.816022 -214.865814  166.763685 -241.970025      0
# 703 -22.149310   53.454764  119.892292  -82.069194  110.979084      3
# 873 -55.652405  149.152560  201.673244 -145.124462  222.315559      3
# 712 -24.430338   71.260834  135.132582  -94.658828  131.158957      3
# 715   1.428646   64.495916  100.373663  -83.113701  113.142317      3
#
# [1000 rows x 12 columns]

# %%
import numpy as np
import random
import pandas as pd
import seaborn as sns
D = 10 #dimensioni
noise = 10.0
mm = [random.randrange(-30, 30)/10  for _ in range(D)]
qq = [random.randrange(-10, 10)/10  for _ in range(D)]
X = np.linspace(-100, 100, 1000)
df = pd.DataFrame(X, columns=['X'])
for i in range(D):
    feature = 'Y'+str(i+1)
    yy = [mm[i]*xi+ qq[i]+ np.random.normal(0, noise) for xi in X]
    df[feature] = yy
#df['X'] = [xi +  np.random.normal(0, noise) for xi in X]
df['label']= [int((xi+120)/50) for xi in X]
df = df.sample(frac=1)

df.to_csv('hyperplane.csv', index = False)
sns.jointplot(x="X", y="Y2", data=df,  hue = df.label)
df['label'].value_counts()
# Out:
# 1    250
# 2    250
# 3    250
# 0    150
# 4    100
# Name: label, dtype: int64

# %% [markdown]
# ## Swiss roll

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets
X, color = datasets.make_swiss_roll(n_samples=5000, noise=2.0)

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=color, cmap=plt.cm.Spectral)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd 
X, color = datasets.make_swiss_roll(n_samples=5000, noise=2.0)
df = pd.DataFrame(X, columns = ['x','y','z'])
df['label']= color
df.to_csv('roll_noise.csv', index=False)

# %%
X, color = datasets.make_swiss_roll(n_samples=5000, noise=0.0)
df = pd.DataFrame(X, columns = ['x','y','z'])
df['label']= color
df.to_csv('roll.csv', index=False)
